# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
npy = np.load("DataSet/No4.npy")

# %%
pk = pd.read_csv("DataSet/pca_knn.csv",index_col=0)
pk.columns = ['n = 1', 'n = 3', 'n = 5', 'n = 7', 'n = 9']

# %%
im = pk.plot(figsize=(12,5))
#plt.title("PCA+KNN")
plt.title("PCA + KNN\n(  train: %d,    test: %d    max = %.2f%%  )"%(1321,789,pk.max().max()*100))
plt.xlabel("K",)
plt.ylabel("P")
plt.savefig("DataSet/image/pca_knn.png")
plt.show()

# %%
import numpy as np
import pandas as pd
import scineo as sn
mat = np.load("DataSet/No4.npy")
# Out:
# (1342, 5184)
