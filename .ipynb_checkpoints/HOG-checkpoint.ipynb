# %%
import scineo as sn
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd

# %%
mat = np.load("DataSet/No4.npy")

# %%
mat
# Out:
# array([ array([[[145, 136, 142, ..., 126, 131, 124],
#         [142, 132, 137, ..., 122, 130, 128],
#         [133, 125, 130, ..., 128, 136, 134],
#         ...,
#         [132, 141, 137, ..., 146, 134, 130],
#         [137, 144, 139, ..., 153, 143, 139],
#         [140, 144, 136, ..., 159, 148, 143]],
#
#        [[133, 128, 125, ..., 128, 132, 124],
#         [123, 116, 115, ..., 131, 137, 129],
#         [127, 120, 119, ..., 128, 133, 127],
#         ...,
#         [169, 177, 167, ..., 119, 126, 139],
#         [165, 175, 169, ..., 111, 116, 129],
#         [159, 165, 165, ..., 104, 109, 116]],
#
#        [[139, 133, 136, ..., 123, 103, 100],
#         [145, 141, 145, ..., 130, 110, 104],
#         [145, 142, 149, ..., 144, 122, 107],
#         ...,
#         [127, 121, 115, ..., 122, 137, 154],
#         [125, 121, 116, ..., 115, 130, 147],
#         [126, 125, 120, ..., 111, 125, 139]],
#
#        ...,
#        [[122, 120, 113, ..., 106, 111, 123],
# ...
